# %% [markdown]
# Step 0 Importing data and libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt
plt.style.use('ggplot')
pd.set_option('display.max_columns', 200)

# %%
df=pd.read_csv("lci-mar26qtr-tables.csv")

# %% [raw]
# df.head(5)

# %%
df.head()
# Out:
#   Series_reference   Period  Data_value STATUS  UNITS  MAGNTUDE  \
# 0      LCIQ.SD53Z9  1992.12  610.484966  FINAL  index         0
# 1      LCIQ.SD53Z9  1993.03  612.316421  FINAL  index         0
# 2      LCIQ.SD53Z9  1993.06  614.147876  FINAL  index         0
# 3      LCIQ.SD53Z9  1993.09  615.368846  FINAL  index         0
# 4      LCIQ.SD53Z9  1993.12  616.589815  FINAL  index         0
#
#                    Subject                                              Group  \
# 0  Labour Cost Index - LCI  All Sectors Combined, All Salary and Wage Rate...
# 1  Labour Cost Index - LCI  All Sectors Combined, All Salary and Wage Rate...
# 2  Labour Cost Index - LCI  All Sectors Combined, All Salary and Wage Rate...
# 3  Labour Cost Index - LCI  All Sectors Combined, All Salary and Wage Rate...
# 4  Labour Cost Index - LCI  All Sectors Combined, All Salary and Wage Rate...
#
#          Series_title_1             Series_title_2  \
# 0  All Sectors Combined  All Salary and Wage Rates
# ...

# %%
df.shape
# Out:
# (32546, 13)

# %%
df.columns
# Out:
# Index(['Series_reference', 'Period', 'Data_value', 'STATUS', 'UNITS',
#        'MAGNTUDE', 'Subject', 'Group', 'Series_title_1', 'Series_title_2',
#        'Series_title_3', 'Series_title_4', 'Series_title_5'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Series_reference     object
# Period              float64
# Data_value          float64
# STATUS               object
# UNITS                object
# MAGNTUDE              int64
# Subject              object
# Group                object
# Series_title_1       object
# Series_title_2       object
# Series_title_3       object
# Series_title_4       object
# Series_title_5       object
# dtype: object

# %%
df.describe()
# Out:
#              Period    Data_value  MAGNTUDE
# count  32546.000000  32534.000000   32546.0
# mean    2014.593977    861.137081       0.0
# std        7.705778    519.959790       0.0
# min     1989.060000      0.000000       0.0
# 25%     2010.120000     59.000000       0.0
# 50%     2015.120000   1078.000000       0.0
# 75%     2021.030000   1211.000000       0.0
# max     2026.030000   1819.000000       0.0

# %%
df.drop(["Series_title_4","Series_title_5"], axis=1)
##dropping single columns
# Out:
#       Series_reference   Period  Data_value STATUS    UNITS  MAGNTUDE  \
# 0          LCIQ.SD53Z9  1992.12  610.484966  FINAL    index         0
# 1          LCIQ.SD53Z9  1993.03  612.316421  FINAL    index         0
# 2          LCIQ.SD53Z9  1993.06  614.147876  FINAL    index         0
# 3          LCIQ.SD53Z9  1993.09  615.368846  FINAL    index         0
# 4          LCIQ.SD53Z9  1993.12  616.589815  FINAL    index         0
# ...                ...      ...         ...    ...      ...       ...
# 32541      LCIQ.SX529A  2025.03   51.000000  FINAL  Percent         0
# 32542      LCIQ.SX529A  2025.06   57.000000  FINAL  Percent         0
# 32543      LCIQ.SX529A  2025.09   56.000000  FINAL  Percent         0
# 32544      LCIQ.SX529A  2025.12   53.000000  FINAL  Percent         0
# 32545      LCIQ.SX529A  2026.03   54.000000  FINAL  Percent         0
#
#                        Subject  \
# 0      Labour Cost Index - LCI
# 1      Labour Cost Index - LCI
# ...

# %%
##rename our columns

# %%
df.rename(columns={'Series_title_1':'Sectors','Series_title_2':'Wage'})
df.drop(['Series_title_4','Series_title_5'],axis=1)

# %%
# Out:
#   Series_reference   Period  Data_value STATUS  UNITS  MAGNTUDE  \
# 0      LCIQ.SD53Z9  1992.12  610.484966  FINAL  index         0
# 1      LCIQ.SD53Z9  1993.03  612.316421  FINAL  index         0
# 2      LCIQ.SD53Z9  1993.06  614.147876  FINAL  index         0
# 3      LCIQ.SD53Z9  1993.09  615.368846  FINAL  index         0
# 4      LCIQ.SD53Z9  1993.12  616.589815  FINAL  index         0
#
#                    Subject                                              Group  \
# 0  Labour Cost Index - LCI  All Sectors Combined, All Salary and Wage Rate...
# 1  Labour Cost Index - LCI  All Sectors Combined, All Salary and Wage Rate...
# 2  Labour Cost Index - LCI  All Sectors Combined, All Salary and Wage Rate...
# 3  Labour Cost Index - LCI  All Sectors Combined, All Salary and Wage Rate...
# 4  Labour Cost Index - LCI  All Sectors Combined, All Salary and Wage Rate...
#
#          Series_title_1             Series_title_2  \
# 0  All Sectors Combined  All Salary and Wage Rates
# ...

# %%
df.head()
# Out:
#   Series_reference   Period  Data_value STATUS  UNITS  MAGNTUDE  \
# 0      LCIQ.SD53Z9  1992.12  610.484966  FINAL  index         0
# 1      LCIQ.SD53Z9  1993.03  612.316421  FINAL  index         0
# 2      LCIQ.SD53Z9  1993.06  614.147876  FINAL  index         0
# 3      LCIQ.SD53Z9  1993.09  615.368846  FINAL  index         0
# 4      LCIQ.SD53Z9  1993.12  616.589815  FINAL  index         0
#
#                    Subject                                              Group  \
# 0  Labour Cost Index - LCI  All Sectors Combined, All Salary and Wage Rate...
# 1  Labour Cost Index - LCI  All Sectors Combined, All Salary and Wage Rate...
# 2  Labour Cost Index - LCI  All Sectors Combined, All Salary and Wage Rate...
# 3  Labour Cost Index - LCI  All Sectors Combined, All Salary and Wage Rate...
# 4  Labour Cost Index - LCI  All Sectors Combined, All Salary and Wage Rate...
#
#                 Sectors                       Wage  \
# 0  All Sectors Combined  All Salary and Wage Rates
# ...

# %%
df.loc[df.duplicated()]
#to check for duploicated values
# Out:
# Empty DataFrame
# Columns: [Series_reference, Period, Data_value, STATUS, UNITS, MAGNTUDE, Subject, Group, Sectors, Wage, Series_title_3]
# Index: []

# %%
df.duplicated(subset=['Series_reference'])
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 32541     True
# 32542     True
# 32543     True
# 32544     True
# 32545     True
# Length: 32546, dtype: bool

# %%
df.loc[df.duplicated(subset=['Series_reference'])].head()
##to display first 5
# Out:
#   Series_reference   Period  Data_value STATUS  UNITS  MAGNTUDE  \
# 1      LCIQ.SD53Z9  1993.03  612.316421  FINAL  index         0
# 2      LCIQ.SD53Z9  1993.06  614.147876  FINAL  index         0
# 3      LCIQ.SD53Z9  1993.09  615.368846  FINAL  index         0
# 4      LCIQ.SD53Z9  1993.12  616.589815  FINAL  index         0
# 5      LCIQ.SD53Z9  1994.03  618.421270  FINAL  index         0
#
#                    Subject                                              Group  \
# 1  Labour Cost Index - LCI  All Sectors Combined, All Salary and Wage Rate...
# 2  Labour Cost Index - LCI  All Sectors Combined, All Salary and Wage Rate...
# 3  Labour Cost Index - LCI  All Sectors Combined, All Salary and Wage Rate...
# 4  Labour Cost Index - LCI  All Sectors Combined, All Salary and Wage Rate...
# 5  Labour Cost Index - LCI  All Sectors Combined, All Salary and Wage Rate...
#
#                 Sectors                       Wage  \
# 1  All Sectors Combined  All Salary and Wage Rates
# ...
